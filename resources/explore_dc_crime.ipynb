# %% [markdown]
# https://opendata.dc.gov/datasets/crime-incidents-in-2019/data

# %%
import pandas as pd
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('Crime_Incidents_in_2019.csv')
df.head(3)
# Out:
#            X          Y       CCN                REPORT_DAT     SHIFT  METHOD  \
# 0 -77.010378  38.820469  17084415  2019-01-28T00:00:00.000Z  MIDNIGHT     GUN
# 1 -76.991741  38.863043  18221852  2019-01-01T02:01:58.000Z  MIDNIGHT  OTHERS
# 2 -76.978998  38.901381  18221856  2019-01-01T03:12:54.000Z  MIDNIGHT  OTHERS
#
#         OFFENSE                                              BLOCK    XBLOCK  \
# 0      HOMICIDE             130 - 199 BLOCK OF IRVINGTON STREET SW  399099.0
# 1  THEFT F/AUTO  2300 2399  BLOCK OF MARTIN LUTHER KING JR AVEN...  400717.0
# 2  THEFT F/AUTO                  900 - 979 BLOCK OF 17TH STREET NE  401822.0
#
#      YBLOCK  ...  BLOCK_GROUP CENSUS_TRACT  VOTING_PRECINCT   LATITUDE  \
# 0  128076.0  ...     010900 2      10900.0     Precinct 126  38.820461
# 1  132802.0  ...     007407 2       7407.0     Precinct 119  38.863036
# 2  137058.0  ...     008904 2       8904.0      Precinct 79  38.901374
#
# ...

# %%
df2=df.groupby(['LATITUDE', 'LONGITUDE'])['REPORT_DAT'].count().reset_index()
df2.columns=['LATITUDE', 'LONGITUDE', 'COUNT']
df2.head(3)
# Out:
#     LATITUDE  LONGITUDE  COUNT
# 0  38.819381 -77.008913     10
# 1  38.820209 -77.007093      1
# 2  38.820461 -77.010375      1

# %%
df2.to_csv('crime_shortdf.csv', index=False)

# %%
crimes =pd.read_csv('crime_shortdf.csv')
crimes.head()
# Out:
#     LATITUDE  LONGITUDE  COUNT
# 0  38.819381 -77.008913     10
# 1  38.820209 -77.007093      1
# 2  38.820461 -77.010375      1
# 3  38.820669 -77.009028      5
# 4  38.820696 -77.007715      1

# %%
# Display as a heatmap 

fig = go.Figure(go.Densitymapbox(lat=crimes['LATITUDE'], 
                                 lon=crimes['LONGITUDE'], 
                                 z=crimes['COUNT'], 
                                 radius=20))
fig.update_layout(mapbox_style="stamen-terrain", 
                  mapbox_center_lon=-77.07,
                  mapbox_center_lat=38.92,
                  mapbox_zoom=11,
                 )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
iplot(fig)
# Out:
# <div>
#
#
#             <div id="382a7131-9620-4235-a988-b7d34ff03156" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("382a7131-9620-4235-a988-b7d34ff03156")) {
#                     Plotly.newPlot(
#                         '382a7131-9620-4235-a988-b7d34ff03156',
# ...
